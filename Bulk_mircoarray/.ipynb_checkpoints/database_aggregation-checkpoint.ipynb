# %% [markdown]
# ## DATA CONDENSTAION ##
#
# ### OBJECTIVES ###
#
# 1. What genes are most represented? Need to get above 5000 genes
#     - Do all GPLs hvae the same gene symbols?
#     - create a definitive gene symbol list

# %%
import re
import pandas as pd
import numpy as np
import pickle
import ntpath
import mysql.connector #maybe unnecessary
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqlconnector://Simon:Bane@localhost/microarray_data_v2')

# %%
#sample meta import
sampleMeta = pd.read_sql_table('master', con=engine)
gse_training = pd.read_excel('../Training/geo-expression-array-immune-cells-studies.xlsx')

# %%
sampleMeta['cell.type']=sampleMeta['cell.type'].apply(lambda x: x.lower())

# %%
gse_training.columns
# Out:
# Index(['gse', 'cell.types', 'n.cell.types', 'title'], dtype='object')

# %%
sampleMeta.head()
# Out:
#   platform_id       gse                                    file         id  \
# 0      GPL570  GSE10021  GSE10021_series_matrix.txt.gz.anno.tsv  GSM253209
# 1      GPL570  GSE10038  GSE10038_series_matrix.txt.gz.anno.tsv  GSM253634
# 2      GPL570  GSE10038  GSE10038_series_matrix.txt.gz.anno.tsv  GSM253635
# 3      GPL570  GSE10038  GSE10038_series_matrix.txt.gz.anno.tsv  GSM253636
# 4      GPL570  GSE10038  GSE10038_series_matrix.txt.gz.anno.tsv  GSM253637
#
#                      col                                pattern  \
# 0  characteristics_ch1_1  \bT.?cell(?!.*lymphoma)(?!.*leukemia)
# 1        source_name_ch1             macrophage(?!.*progenitor)
# 2        source_name_ch1             macrophage(?!.*progenitor)
# 3        source_name_ch1             macrophage(?!.*progenitor)
# 4        source_name_ch1             macrophage(?!.*progenitor)
#
#                     hit   cell.type  \
# 0      from T cell luke     t_cells
# 1  olar macrophages obt  macrophage
# 2  olar macrophages obt  macrophage
# 3  olar macrophages obt  macrophage
# 4  olar macrophages obt  macrophage
#
#                                                  val               technology  \
# 0  human cultured cell line derived from T cell l...  in situ oligonucleotide
# 1  alveolar macrophages obtained by bronchoscopy ...  in situ oligonucleotide
# 2  alveolar macrophages obtained by bronchoscopy ...  in situ oligonucleotide
# 3  alveolar macrophages obtained by bronchoscopy ...  in situ oligonucleotide
# 4  alveolar macrophages obtained by bronchoscopy ...  in situ oligonucleotide
#
#                                                title normalization
# 0  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 1  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...          MAS5
# 2  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...          MAS5
# 3  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...          MAS5
# 4  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...          MAS5

# %%
sampleMeta['platform_id'].unique()
# Out:
# array(['GPL570', 'GPL571', 'GPL6244', 'GPL96', 'GPL97'], dtype=object)

# %%
list(map(lambda x: x.lower(), sampleMeta[sampleMeta['platform_id']=='GPL570']['gse'].unique()))
# Out:
# ['gse10021',
#  'gse10038',
#  'gse49954',
#  'gse10046',
#  'gse100786',
#  'gse10147',
#  'gse101587',
#  'gse10178',
#  'gse101855',
#  'gse13576',
#  'gse102459',
#  'gse51382',
#  'gse10315',
#  'gse10316',
#  'gse35340',
#  'gse103381',
#  'gse65856',
#  'gse13670',
#  'gse10358',
#  'gse10437',
#  'gse36767',
#  'gse10463',
#  'gse10479',
#  'gse10524',
#  'gse105437',
#  'gse10586',
#  'gse10595',
#  'gse106151',
#  'gse22045',
#  'gse106382',
#  'gse22167',
#  'gse106532',
#  'gse10767',
#  'gse22373',
#  'gse107683',
#  'gse107818',
#  'gse10821',
#  'gse10831',
#  'gse108384',
#  'gse10846',
#  'gse10880',
#  'gse10896',
#  'gse109178',
#  'gse10927',
#  'gse109348',
#  'gse109662',
#  'gse109836',
#  'gse110023',
#  'gse110064',
#  'gse110085',
#  'gse110376',
#  'gse110545',
#  'gse11057',
#  'gse11083',
#  'gse11118',
#  'gse11151',
#  'gse11190',
#  'gse112209',
#  'gse112210',
#  'gse112809',
#  'gse11281',
#  'gse11292',
#  'gse112953',
#  'gse11327',
#  'gse113645',
#  'gse11373',
#  'gse11418',
#  'gse114181',
#  'gse11430',
#  'gse23371',
#  'gse116487',
#  'gse116660',
#  'gse116912',
#  'gse117139',
#  'gse11755',
#  'gse11761',
#  'gse117676',
#  'gse11854',
#  'gse11864',
#  'gse11881',
#  'gse11886',
#  'gse118958',
#  'gse11919',
#  'gse24223',
#  'gse119416',
#  'gse12079',
#  'gse12108',
#  'gse12131',
#  'gse12187',
#  'gse12195',
#  'gse12198',
#  'gse12293',
#  'gse12366',
#  'gse12488',
#  'gse12507',
#  'gse12583',
#  'gse72642',
#  'gse25087',
#  'gse12662',
#  'gse12679',
#  'gse12734',
#  'gse12773',
#  'gse12806',
#  'gse12838',
#  'gse16385',
#  'gse12846',
#  'gse12875',
#  'gse12891',
#  'gse25638',
#  'gse12963',
#  'gse13054',
#  'gse13139',
#  'gse13210',
#  'gse13234',
#  'gse13296',
#  'gse13300',
#  'gse13330',
#  'gse26347',
#  'gse13501',
#  'gse26928',
#  'gse13606',
#  'gse13637',
#  'gse13712',
#  'gse13727',
#  'gse13732',
#  'gse13736',
#  'gse13738',
#  'gse13762',
#  'gse13791',
#  'gse13828',
#  'gse13837',
#  'gse13849',
#  'gse13887',
#  'gse13896',
#  'gse13899',
#  'gse13906',
#  'gse13909',
#  'gse13917',
#  'gse13931',
#  'gse13987',
#  'gse14000',
#  'gse14062',
#  'gse27928',
#  'gse28490',
#  'gse28491',
#  'gse14596',
#  'gse14924',
#  'gse14926',
#  'gse19246',
#  'gse15659',
#  'gse42203',
#  'gse56767',
#  'gse42253',
#  'gse16130',
#  'gse16461',
#  'gse65135',
#  'gse17186',
#  'gse17269',
#  'gse17549',
#  'gse19067',
#  'gse19069',
#  'gse31773',
#  'gse95298',
#  'gse47855',
#  'gse47920',
#  'gse9801',
#  'gse19599',
#  'gse49910',
#  'gse64555',
#  'gse51288',
#  'gse51997',
#  'gse67321',
#  'gse4588',
#  'gse67596',
#  'gse36907',
#  'gse56314',
#  'gse55673',
#  'gse33536',
#  'gse7307',
#  'gse26050',
#  'gse26156',
#  'gse26495',
#  'gse44126',
#  'gse59412',
#  'gse94510',
#  'gse28726',
#  'gse56313',
#  'gse41831',
#  'gse41889',
#  'gse29301',
#  'gse93984',
#  'gse60920',
#  'gse84331',
#  'gse85074',
#  'gse93683',
#  'gse42733',
#  'gse45535',
#  'gse76492',
#  'gse4527',
#  'gse59786',
#  'gse94801',
#  'gse61697',
#  'gse6743',
#  'gse83441',
#  'gse93776',
#  'gse74266',
#  'gse65010',
#  'gse47796',
#  'gse42672',
#  'gse71566',
#  'gse64028',
#  'gse98640',
#  'gse9891',
#  'gse50175',
#  'gse82159',
#  'gse58173',
#  'gse43769',
#  'gse79706',
#  'gse7753',
#  'gse59051',
#  'gse43346',
#  'gse73927',
#  'gse71730']

# %% [markdown]
#  ### GENERAL ATTRIBUTES ###
#
#  __GPL570__
#  - lots of GSEs
#  - 22899 genes
#
#  __GPL571__
#  - fewer GSEs
#  - 13277 genes
#
#  __GPL6244__
#  - 1 GSE
#
#  __GPL96__
#  - decent amount of GSEs
#  - same gene # as GPL571, 13277
#      -- though some are in the 22000 range
#
#  __GPL97__
#  - handful of GSEs
#  - also 13277
#
#  ### COMBINATIONS ###
#
#  - GPL97 and GPL96 *seem* to combine well
#  - GPL96 and GPL571 *seem* to combine well
#  - it appears that most--if not all--of the '13000' gene symbol sets are included in the 22000 gene symbol sets

# %%
engine.table_names()
# Out:
# ['gse10021',
#  'gse10038',
#  'gse10040',
#  'gse10046',
#  'gse100786',
#  'gse10125',
#  'gse10147',
#  'gse101587',
#  'gse10172',
#  'gse10178',
#  'gse101855',
#  'gse102459',
#  'gse10315',
#  'gse10316',
#  'gse10325',
#  'gse103381',
#  'gse10358',
#  'gse10437',
#  'gse10463',
#  'gse10479',
#  'gse10524',
#  'gse105437',
#  'gse10586',
#  'gse10595',
#  'gse10612',
#  'gse106151',
#  'gse10631',
#  'gse106382',
#  'gse106532',
#  'gse10767',
#  'gse107683',
#  'gse10778',
#  'gse107818',
#  'gse10804',
#  'gse10821',
#  'gse10831',
#  'gse108384',
#  'gse10846',
#  'gse10880',
#  'gse10896',
#  'gse109178',
#  'gse10927',
#  'gse109348',
#  'gse10957',
#  'gse109662',
#  'gse109836',
#  'gse110023',
#  'gse110064',
#  'gse110085',
#  'gse110376',
#  'gse110545',
#  'gse11057',
#  'gse11083',
#  'gse11118',
#  'gse11151',
#  'gse11188',
#  'gse11190',
#  'gse112209',
#  'gse112210',
#  'gse112809',
#  'gse11281',
#  'gse11292',
#  'gse112953',
#  'gse11327',
#  'gse1133',
#  'gse11341',
#  'gse11342',
#  'gse113645',
#  'gse11373',
#  'gse11418',
#  'gse114181',
#  'gse11430',
#  'gse11450',
#  'gse116487',
#  'gse116660',
#  'gse116912',
#  'gse117139',
#  'gse11755',
#  'gse11761',
#  'gse11767',
#  'gse117676',
#  'gse11854',
#  'gse11864',
#  'gse11881',
#  'gse11886',
#  'gse118958',
#  'gse11909',
#  'gse11919',
#  'gse119416',
#  'gse11943',
#  'gse12079',
#  'gse12108',
#  'gse12131',
#  'gse12187',
#  'gse12195',
#  'gse12198',
#  'gse12246',
#  'gse12293',
#  'gse12366',
#  'gse12484',
#  'gse12488',
#  'gse12507',
#  'gse12583',
#  'gse12585',
#  'gse12586',
#  'gse12662',
#  'gse12668',
#  'gse12679',
#  'gse71730',
#  'gse72642',
#  'gse7307',
#  'gse73927',
#  'gse74266',
#  'gse76492',
#  'gse7753',
#  'gse79706',
#  'gse82159',
#  'gse8286',
#  'gse83441',
#  'gse84331',
#  'gse85074',
#  'gse8835',
#  'gse8921',
#  'gse93683',
#  'gse93776',
#  'gse9378',
#  'gse93984',
#  'gse94510',
#  'gse94801',
#  'gse95298',
#  'gse9801',
#  'gse98640',
#  'gse9891',
#  'gse9946',
#  'master',
#  'master_test']

# %%
# len(gse_df['gene_symbol_sql'])
gse_df = pd.read_sql_table('gse10021', con=engine)
geneSymbolList = set(gse_df['gene_symbol_sql'])
len(geneSymbolList)
# Out:
# 22899

# %%
gselist = [x for x in engine.table_names() if 'gse' in x]
# geneSymbolList was initialized above
for gse in gselist:
    print(gse)
    gse_df = pd.read_sql_table(gse, con=engine)
    gse_gs = set(gse_df['gene_symbol_sql'])
    # how many gene symbols are not in geneSymbolList?
    new_geneSymbols = gse_gs.difference(geneSymbolList)
    print("not in genesymbollist:")
    print(len(new_geneSymbols))
    # how much bigger does geneSymbolList get after union?
    geneSymbolList = geneSymbolList.union(gse_gs)
    print("new geneSymbolList length:")
    print(len(geneSymbolList))
# Out:
# gse10021
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10038
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10040
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10046
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse100786
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10125
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10147
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse101587
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10172
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10178
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse101855
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse102459
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10315
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10316
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10325
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse103381
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10358
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10437
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10463
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10479
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10524
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse105437
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10586
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10595
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10612
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse106151
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10631
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse106382
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse106532
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10767
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse107683
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10778
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse107818
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10804
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10821
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10831
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse108384
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10846
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10880
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10896
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse109178
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10927
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse109348
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse10957
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse109662
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse109836
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse110023
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse110064
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse110085
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse110376
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse110545
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11057
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11083
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11118
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11151
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11188
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11190
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse112209
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse112210
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse112809
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11281
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11292
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse112953
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11327
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse1133
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11341
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11342
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse113645
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11373
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11418
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse114181
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11430
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11450
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse116487
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse116660
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse116912
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse117139
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11755
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11761
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11767
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse117676
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11854
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11864
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11881
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11886
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse118958
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11909
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11919
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse119416
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse11943
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12079
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12108
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12131
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12187
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12195
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12198
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12246
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12293
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12366
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12484
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12488
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12507
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12583
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12585
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12586
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12662
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12668
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12679
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12734
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12773
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12803
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12806
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12838
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12839
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12845
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12846
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12875
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12891
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12907
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse12963
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13017
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13054
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13139
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13210
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13234
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13296
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13300
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13330
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13411
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13496
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13501
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13576
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13591
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13606
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13637
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13670
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13712
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13727
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13732
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13736
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13738
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13762
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13791
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13828
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13837
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13849
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13850
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13887
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13896
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13899
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13906
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13909
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13917
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13931
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13987
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse13996
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14000
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14062
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14230
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14256
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14330
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14334
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14335
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14340
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14386
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14390
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14405
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14419
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14465
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14479
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14577
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14596
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14630
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14642
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14711
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14801
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14816
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14827
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14895
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14897
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14924
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse14926
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15072
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15174
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15215
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15245
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15322
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15389
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15400
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15464
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15490
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15495
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15499
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15537
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15615
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15645
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15659
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15743
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15777
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15928
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse15949
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse16032
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse16051
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse16093
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse16098
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse16111
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse16129
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse16130
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse16214
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse16226
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse16250
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse16354
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse16355
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse16356
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse16382
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse16385
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse16386
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# gse16416
# not in genesymbollist:
# 0
# new geneSymbolList length:
# 22899
# g
#   'naive_cd4_t_cells',
#   'th1_cells',
#   'th2_cells',
#   'cd4_t_cells',
#   'tregs',
#   'central_memory_cd4_t_cells',
#   'effector_memory_cd4_t_cells',
#   'follicular_helper_t_cells',
#   'th1th17_cells',
#   'effector_cd4_t_cells'],
#  'CD8.T.cells': ['cd8_t_cells',
#   'naive_cd8_t_cells',
#   'effector_memory_cd8_t_cells',
#   'memory_cd8_t_cells',
#   'central_memory_cd8_t_cells'],
#  'NK.cells': ['nk_cells'],
#  'B.cells': ['b_cells',
#   'naive_b_cells',
#   'gc_b_cells',
#   'memory_b_cells',
#   'immature_b_cells',
#   'activated_b_cells',
#   'plasma_b_cells',
#   'resting_b_cells',
#   'pre-gc_b_cells'],
#  'monocytic.lineage': ['monocytes',
#   'dendritic_cells',
#   'macrophage',
#   'immature_dendritic_cells',
#   'myeloid_dendritic_cells',
#   'activated_macrophages'],
#  'neutrophils': ['neutrophils', 'granulocytes'],
#  'endothelial.cells': ['endothelial'],
#  'fibroblasts': ['fibroblast']}

# %%
# get neutrophil GSEs
sampleMeta[sampleMeta['cell.type']=='Granulocytes']
# GSE11083
# - get relevant GSMs from GSE
# Out:
#      platform_id       gse                                    file  \
# 3529      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 3530      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 3531      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 3532      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 3533      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 3534      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 3535      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 3536      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 3537      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 3538      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 3539      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 3540      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 3791      GPL570  GSE45535  GSE45535_series_matrix.txt.gz.anno.tsv
# 3792      GPL570  GSE45535  GSE45535_series_matrix.txt.gz.anno.tsv
# 4437      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4438      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4439      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4488      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4489      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4490      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4563      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4564      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4565      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4611      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4612      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4613      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4614      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4615      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4616      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4667      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4668      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4669      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4670      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4748      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4749      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4753      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
# 4833      GPL570  GSE41831  GSE41831_series_matrix.txt.gz.anno.tsv
#
#               id                            col                      pattern  \
# 3529  GSM1025152  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 3530  GSM1025153  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 3531  GSM1025154  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 3532  GSM1025155  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 3533  GSM1025156  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 3534  GSM1025157  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 3535  GSM1025158  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 3536  GSM1025159  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 3537  GSM1025160  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 3538  GSM1025161  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 3539  GSM1025162  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 3540  GSM1025163  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 3791  GSM1108140  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 3792  GSM1108146  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4437  GSM1025135  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4438  GSM1025142  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4439  GSM1025151  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4488  GSM1025134  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4489  GSM1025136  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4490  GSM1025137  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4563  GSM1025138  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4564  GSM1025139  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4565  GSM1025146  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4611  GSM1025140  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4612  GSM1025143  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4613  GSM1025144  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4614  GSM1025145  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4615  GSM1025147  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4616  GSM1025148  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4667  GSM1025129  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4668  GSM1025130  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4669  GSM1025133  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4670  GSM1025141  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4748  GSM1025131  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4749  GSM1025132  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4753  GSM1025150  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
# 4833  GSM1025149  characteristics_ch1_cell.type  granulocyte(?!.*progenitor)
#
#                hit     cell.type           val               technology  \
# 3529  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 3530  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 3531  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 3532  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 3533  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 3534  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 3535  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 3536  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 3537  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 3538  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 3539  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 3540  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 3791  Granulocytes  Granulocytes  Granulocytes  in situ oligonucleotide
# 3792  Granulocytes  Granulocytes  Granulocytes  in situ oligonucleotide
# 4437  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4438  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4439  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4488  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4489  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4490  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4563  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4564  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4565  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4611  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4612  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4613  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4614  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4615  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4616  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4667  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4668  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4669  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4670  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4748  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4749  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4753  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
# 4833  granulocytes  Granulocytes  granulocytes  in situ oligonucleotide
#
#                                                   title normalization
# 3529  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 3530  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 3531  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 3532  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 3533  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 3534  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 3535  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 3536  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 3537  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 3538  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 3539  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 3540  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 3791  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...       unknown
# 3792  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...       unknown
# 4437  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4438  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4439  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4488  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4489  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4490  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4563  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4564  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4565  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4611  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4612  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4613  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4614  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4615  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4616  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4667  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4668  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4669  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4670  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4748  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4749  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4753  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA
# 4833  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...           RMA

# %%
def format_df(gse, sub_ct):
    print(gse)
    df = pd.read_sql_table(gse.lower(), con=engine)
    df.set_index('gene_symbol_sql', inplace=True)
    gsm_idx = sampleMeta[sampleMeta['cell.type']==sub_ct][sampleMeta['gse']==gse]['id']
    #apparently GSMs in sampleMeta are not present in some GSE dfs
    gsm_idx = [g for g in gsm_idx if g in df.columns]
    df = df[gsm_idx].T
    return df

# %%
# format the first dataframe
for cell in ctDict['Coarse'].keys():
    print(cell)
    gse_dfs=[]
    for sub_ct in ctDict['Coarse'][cell]:
        gse_list = sampleMeta[sampleMeta['cell.type']==sub_ct]['gse'].unique()
        gse_dfs.extend(list(map(lambda x: format_df(x, sub_ct), gse_list)))
        print(len(gse_list))
    #     gse_dfs[:] = [g for g in gse_dfs if g != None]

    ct_master = pd.concat(gse_dfs)
    print(ct_master.shape)
    
    # drop bad samples... 
    gsm_nas = ct_master.apply(lambda x: sum(np.isnan(x)),1)
    gsm_idx = gsm_nas[gsm_nas < 5000].index
    # drop the bad genes
    GS_nas = ct_master.loc[gsm_idx].apply(lambda x: sum(np.isnan(x)))
    GS_idx = GS_nas[GS_nas == 0].index

    ct_filtered = ct_master.loc[gsm_idx, GS_idx]
    print(ct_filtered.shape)
    
    filepath = ntpath.join('picklejar',cell+'.pckl')
    with open(filepath, 'wb') as f:
        pickle.dump(ct_filtered, f)
# Out:
# CD4.T.cells
# GSE36767
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# GSE26928
# GSE15659
# GSE44126
# GSE60920
# GSE22886
# 6
# GSE110545
# 1
# GSE22045
# GSE109348
# GSE25087
# GSE26928
# GSE13732
# GSE94510
# GSE71566
# GSE93776
# GSE13017
# 9
# GSE50175
# GSE43769
# GSE22886
# GSE3982
# 4
# GSE109348
# GSE43769
# GSE22886
# GSE3982
# 4
# GSE10437
# GSE36767
# GSE11292
# GSE117139
# GSE119416
# GSE12079
# GSE12488
# GSE72642
# GSE12875
# GSE12963
# GSE27928
# GSE28490
# GSE28491
# GSE14924
# GSE14926
# GSE15659
# GSE42253
# GSE16130
# GSE16461
# GSE19069
# GSE31773
# GSE47920
# GSE49954
# GSE51288
# GSE67321
# GSE4588
# GSE7307
# GSE49910
# GSE26156
# GSE28726
# GSE60920
# GSE4527
# GSE59786
# GSE71566
# GSE51997
# GSE58173
# GSE93776
# GSE73927
# GSE14330
# GSE62584
# GSE22886
# GSE8835
# GSE10325
# GSE1133
# GSE4571
# GSE6740
# GSE17354
# GSE46917
# 48
# GSE10586
# GSE22045
# GSE11292
# GSE25087
# GSE13234
# GSE15659
# GSE59786
# GSE65010
# GSE73927
# GSE14330
# GSE24634
# GSE13017
# GSE4571
# GSE4527
# 14
# GSE26928
# GSE94510
# 2
# GSE26928
# GSE94510
# 2
# GSE73927
# 1
# GSE50175
# 1
# 0
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   