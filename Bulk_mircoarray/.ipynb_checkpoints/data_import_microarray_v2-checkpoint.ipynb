# %%
import re
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# ### BACKGROUND ###
#
# Make a database of microarray data similar to the RNA-seq database
#
# __VERSION 2__
#
# Restructured the database to include individual GEO records and one master table to point at records

# %%
#READ IN METADATA
gse_training = pd.read_excel('../../Synapse_tumor_deconv/Training/geo-expression-array-immune-cells-studies.xlsx')
sampleMeta = pd.read_excel('../../Synapse_tumor_deconv/Training/geo-expression-array-immune-cells.xlsx')

# %%
sampleMeta['cell.type'].unique()
# Out:
# array(['NK_cells', 'fibroblast', 'Monocytes', 'CD8_T_cells', 'B_cells',
#        'Dendritic_cells', 'endothelial', 'PBMC', 'Memory_CD4_T_cells',
#        'Th17_cells', 'Naive_CD4_T_cells', 'Th1_cells', 'Th2_cells',
#        'CD4_T_cells', 'Macrophage', 'Neutrophils', 'Granulocytes',
#        'T_cells', 'Central_Memory', 'Plasmacytoid_Dendritic_Cells',
#        'Plasma_cells', 'Tregs', 'Basophils', 'Mast_cells',
#        'Naive_B_cells', 'GC_B_cells', 'Memory_B_cells', 'Plasmablast',
#        'Immature_B_cells', 'White_blood_cells', 'Activated_B_cells',
#        'Immature_Dendritic_cells', 'Myeloid_Dendritic_cells',
#        'Eosinophils', 'Effector_Memory_T_cells', 'Central_Memory_T_cells',
#        'Effector_Memory', 'Plasma_B_cells', 'Naive_CD8_T_cells',
#        'Central_Memory_CD4_T_cells', 'Effector_Memory_CD4_T_cells',
#        'gamma_delta_T_cells', 'Resting_B_cells', 'Activated_T_cells',
#        'Memory_T_cells', 'Naive_T_cells', 'NKT_cells',
#        'Effector_Memory_CD8_T_cells', 'Memory_CD8_T_cells',
#        'Follicular_helper_T_cells', 'Th1Th17_cells',
#        'Central_Memory_CD8_T_cells', 'Activated_Macrophages',
#        'Effector_CD4_T_cells', 'pre-GC_B_cells'], dtype=object)

# %%
sampleMeta['cell.type'] = sampleMeta['cell.type'].apply(lambda x: re.sub(' ','_',x)).values
sampleMeta.head()
# Out:
#   platform_id       gse                                    file         id  \
# 0    GPL10175  GSE20874  GSE20874_series_matrix.txt.gz.anno.tsv  GSM521965
# 1    GPL10175  GSE20874  GSE20874_series_matrix.txt.gz.anno.tsv  GSM521969
# 2    GPL10175  GSE20874  GSE20874_series_matrix.txt.gz.anno.tsv  GSM521979
# 3    GPL10175  GSE20874  GSE20874_series_matrix.txt.gz.anno.tsv  GSM521980
# 4    GPL10666  GSE23034  GSE23034_series_matrix.txt.gz.anno.tsv  GSM568491
#
#                              col       pattern                   hit  \
# 0                          title    NK(_|-|\b)             2656_NK-T
# 1                          title    NK(_|-|\b)             4221_NK-T
# 2                          title    NK(_|-|\b)             3168_NK-T
# 3                          title    NK(_|-|\b)             8144_NK-T
# 4  characteristics_ch1_cell.type  \bfibroblast  skin fibroblast-deri
#
#     cell.type                                   val               technology  \
# 0    NK_cells                            12656_NK-T  in situ oligonucleotide
# 1    NK_cells                            14221_NK-T  in situ oligonucleotide
# 2    NK_cells                             3168_NK-T  in situ oligonucleotide
# 3    NK_cells                             8144_NK-T  in situ oligonucleotide
# 4  fibroblast  foreskin fibroblast-derived iPS cell  in situ oligonucleotide
#
#                                                title
# 0  Affymetrix Human Genome U133 Plus 2.0 Array [M...
# 1  Affymetrix Human Genome U133 Plus 2.0 Array [M...
# 2  Affymetrix Human Genome U133 Plus 2.0 Array [M...
# 3  Affymetrix Human Genome U133 Plus 2.0 Array [M...
# 4  Affymetrix Human Gene ST 1.0 Custom RefSeq CDF...

# %%
gse_sample=gse_training.sample(20)

# %%
gse_training.head()
# Out:
#          gse                                         cell.types  n.cell.types  \
# 0  GSE109348  B cells, Basophils, CD8 T cells, Central Memor...            14
# 1   GSE22886  CD4 T cells, CD8 T cells, Dendritic cells, Mac...            13
# 2    GSE3982  B cells, Basophils, Central Memory T cells, De...            13
# 3   GSE28490  B cells, CD4 T cells, CD8 T cells, Eosinophils...             9
# 4   GSE28492  B cells, CD4 T cells, CD8 T cells, Eosinophils...             9
#
#                                                title
# 0  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...
# 1     [HG-U133A] Affymetrix Human Genome U133A Array
# 2     [HG-U133A] Affymetrix Human Genome U133A Array
# 3  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...
# 4  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...

# %% [markdown]
# ### GETTING THE DATA ###

# %%
import os
import subprocess
import ntpath
import shutil
import GEOparse
import mygene
from progressbar import ProgressBar
import mysql.connector #maybe unnecessary
from sqlalchemy import create_engine
# from sqlalchemy.orm import sessionmaker

# %%
# outdir = '-o'+ntpath.join('tmp','raw_output')
# #need to add more patterns:
# genePattern = re.compile('(?i)ensg|NM_|enst')

# %%
# FUNCTION TO START NEW GSE RECORD IN LOG FILE
def logNewGSE(of,gse):
    of.write('--------------------------\n')
    of.write('GSENAME__'+gse+'\n')
    of.write('--------------------------\n')

# %%
def clean_tmp_files():
    for f in os.listdir('./'):
        if '.soft' in f:
            try:
                os.remove(f)
            except:
                continue

# %%
def checkData(gse, gse_meta, sampleMeta, stopToken, of):
    # superseries check
    if re.search('(?i)superseries', str(gse.metadata['summary'])):
        of.write('SKIPPED:'+gse.get_accession()+' checkData(): gse is superseries')
        stopToken = 1
        return None, None, stopToken
    # use only human samples...This should be redudant as the platform should be human specific
    # use the correct platform
    try:
        platform_title = gse_meta['title'].values[0]
        gpl_id = None
        for gpl, meta in gse.gpls.items():
            if meta.metadata['title'][0] == platform_title:
                gpl_id = gpl
                gse_meta['gpl'] = gpl
        gsm_ix = gse.phenotype_data[gse.phenotype_data['platform_id']==gpl_id].index.to_numpy()
        cds = gse.pivot_samples('VALUE')[gsm_ix]
        cds_gsms = set(cds.columns.to_numpy())
        gsm_ix = list(cds_gsms.intersection(set(sampleMeta['id'])))
        cds = cds.loc[:,gsm_ix]
    except:
        of.write('SKIPPED:'+gse.get_accession()+' checkData(): Could not find the platform')
        stopToken = 1
        return None, None, stopToken
    return cds, gse_meta, stopToken

# %%
def checkScale(gse, cds, stopToken, of):
    scale_dict = {'log2':[], 'log10':[], 'linear':[]}
    try:
        if gse.phenotype_data.loc[cds.columns]['data_processing'].nunique() > 1:
            for gsm in cds.columns.to_numpy():
                if 'log2' in gse.gsms[gsm].columns.loc['VALUE','description']:
                    scale_dict['log2'].append(gsm)
                elif 'log10' in gse.gsms[gsm].columns.loc['VALUE','description']:
                    scale_dict['log10'].append(gsm)
                elif 'log' in gse.gsms[gsm].columns.loc['VALUE','description']:
                    scale_dict['log2'].append(gsm)
                else:
                    scale_dict['linear'].append(gsm)
        else:
            # doesn't actually have to be linear
            scale_dict['linear'].extend(cds.columns.to_numpy())
        cds_linear = cds.loc[:,scale_dict['linear']]
        qx = cds_linear.quantile([0., 0.25, 0.5, 0.75, 0.99, 1.0]).apply(np.mean, 1)
        if any(cds < 0):
            # Weird dataset
            pass
        # Test for log10...
        logTest = any([qx.iloc[4]>100, 
                       (qx.iloc[5]-qx.iloc[0] > 50 and qx.iloc[1] > 0),
                      (qx.iloc[1] > 0 and qx.iloc[1] < 1 and qx.iloc[3] > 1 and qx.iloc[3] < 2)])
        if logTest:
            cds_linear = np.log2(cds_linear)
            cds.loc[:,cds_linear.columns] = cds_linear
        else:
            of.write('checkScale(): assumed log2 transform \n')
    #     cds.replace([np.inf, -np.inf], np.nan)
    #     cds.dropna(inplace=True)
        cds = cds[~cds.isin([np.nan, np.inf, -np.inf]).any(1)]
    except:
        of.write('SKIPPED: '+gse.get_accession()+'c heckScale(): unknown issue \n')
        stopToken = 1
        return None, stopToken
    return cds, stopToken

# %%
def getNormalization(gse, cds, of):
    gse_norm = 'unknown'
    if 'data_processing' in gse.phenotype_data.columns:
        data_processing = gse.phenotype_data.loc[cds.columns]['data_processing'][0]
        if re.search('RMA', data_processing):
    #         gse_norm = re.search(r'(RMA\W?\w+)', data_processing).group(0)
            if re.search('(?i)gcrma', data_processing):
                gse_norm = 'gcRMA'
            else:
                gse_norm = 'RMA'
        elif re.search('(?i)(Robust Multi-Chip Average)', data_processing):
            if re.search('(?i)quantile', data_processing):
                gse_norm = 'RMA-quantile'
            else:
                gse_norm = 'RMA'
        elif re.search('(?i)MAS', data_processing):
            gse_norm = 'MAS5'
    if gse_norm == 'unknown':
        of.write('getNormalization(): Not sure about the normalization \n')
    return gse_norm

# %%
def getGeneNames(gse, df, gse_meta, stopToken, of):
    try:
        gpl = gse.gpls[gse_meta['gpl'].values[0]].table
        gpl.set_index('ID', inplace=True)
        gpl = gpl.loc[df.index]
        if 'Gene Symbol' in gpl.columns:
            df['gene_symbol_sql'] = gpl['Gene Symbol'].apply(lambda x: str(x).split('///')[-1].strip(), 1).to_numpy()
            #drop blanks of nans
            df = df[df['gene_symbol_sql']!=('nan' or "")]
#             gs_VC=df['gene_symbol_sql'].value_counts()
#             pbar = ProgressBar()
#             for gs in pbar(gs_VC.loc[gs_VC>1].index):
#                 gs_idx=df.loc[df['gene_symbol_sql']==gs].index
#                 # CHECKPOINT: make sure we're dealing with floats as count type
#                 gs_mean = df.loc[gs_idx].select_dtypes(include=['float']).mean()
#                 df.loc[gs_idx[0], gs_mean.index] = gs_mean
#                 df.drop(gs_idx[1:], inplace=True)
            df = df.groupby('gene_symbol_sql').mean()
        else:
            of.write('SKIPPED: getGeneNames() Can\'t find Gene Symbols \n')
            stopToken = 1
            return df, stopToken
    except:
        pass
        of.write('SKIPPED: '+gse.get_accession()+' getGeneNames() Something went wrong')
        stopToken = 1
        return None, stopToken
    return df, stopToken

# %%
def writeDataToSQL(df, sampleMeta, gse_acc, stopToken, of):
    try:
        #associate ct with each GSM
    #     gsm_IDs = list(map(lambda x: x.split('_')[4], df.columns))
        #I hate this section so much...but I'm tired...
        ct_dict = {}
        for c in df.columns:
            gsm_ID = c.split('_')[4]
            ct = sampleMeta[sampleMeta['id']==gsm_ID]['cell.type'].values[0]
            ct = re.sub(' ','_',ct)
            if ct in ct_dict.keys():
                ct_dict[ct].append(c)
            else:
                ct_dict[ct] = [c]
    #     return ct_dict
        for ct in ct_dict.keys():
            ct_cols = ct_dict[ct]
            ct_cds = df[ct_cols]
            ct_cds.columns.name = None
            ct_cds.reset_index(inplace=True)
            if all(ct.lower() != cellType for cellType in engine.table_names()):
                ct_cds.to_sql(ct.lower(), con=engine, chunksize=2000)
    #             return ct_cds.head()
            else:
                sql_df = pd.read_sql_table(ct.lower(), con=engine)
                sql_df.drop('index', 1, inplace=True)
    #             sql_df.set_index('gene_symbol_sql', inplace=True)
                if any(sql_df.columns.str.contains(gse_acc)):
                    of.write('SKIPPED: ('+gse_acc+') writeDataToSQL() GSE already exists in table \n')
                    continue
                max_size = sql_df.shape[0]
                cds_for_sql = sql_df.merge(ct_cds,how='outer',on='gene_symbol_sql')
                if sum(cds_for_sql.duplicated()) == 0 and cds_for_sql.shape[0] > 1:
    #                 cds_for_sql.drop(columns=['index'], inplace=True)
                    cds_for_sql.to_sql(ct.lower(),con=engine, if_exists='replace',chunksize=2000)
                else:
                    stopToken=1
                    of.write('SKIPPED: ('+gse_acc+') writeDataToSQL() '+ct+' There is something strange about the data merge \n')
    except:
        of.write('SKIPPED: ('+gse_acc+') writeDataToSQL() I don\'t know.... \n')
    return stopToken

# %%
gse_training.head(20)
# Out:
#           gse                                         cell.types  \
# 0   GSE109348  B cells, Basophils, CD8 T cells, Central Memor...
# 1    GSE22886  CD4 T cells, CD8 T cells, Dendritic cells, Mac...
# 2     GSE3982  B cells, Basophils, Central Memory T cells, De...
# 3    GSE28490  B cells, CD4 T cells, CD8 T cells, Eosinophils...
# 4    GSE28492  B cells, CD4 T cells, CD8 T cells, Eosinophils...
# 5    GSE28491  B cells, CD4 T cells, CD8 T cells, Eosinophils...
# 6     GSE7307  B cells, CD4 T cells, CD8 T cells, endothelial...
# 7    GSE93776  CD4 T cells, CD8 T cells, Monocytes, Naive CD4...
# 8    GSE93777  CD4 T cells, CD8 T cells, Monocytes, Naive CD4...
# 9    GSE58173  B cells, CD4 T cells, CD8 T cells, Monocytes, ...
# 10   GSE72642  B cells, CD4 T cells, CD8 T cells, Monocytes, ...
# 11   GSE45535  B cells, Granulocytes, Monocytes, Plasma cells...
# 12   GSE45537  B cells, Granulocytes, Monocytes, Plasma cells...
# 13   GSE49910  B cells, CD4 T cells, CD8 T cells, Monocytes, ...
# 14   GSE56315  B cells, GC B cells, Memory B cells, Naive B c...
# 15   GSE67321  B cells, CD4 T cells, CD8 T cells, Monocytes, ...
# 16  GSE107843  B cells, Immature B cells, Memory B cells, Nai...
# 17    GSE1133   CD4 T cells, CD8 T cells, endothelial, Monocytes
# 18   GSE12195  B cells, GC B cells, Memory B cells, Naive B c...
# 19   GSE12366  GC B cells, Memory B cells, Naive B cells, Pla...
#
#     n.cell.types                                              title
# 0             14  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...
# 1             13     [HG-U133A] Affymetrix Human Genome U133A Array
# 2             13     [HG-U133A] Affymetrix Human Genome U133A Array
# 3              9  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...
# 4              9  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...
# 5              7  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...
# 6              7  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...
# 7              7  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...
# 8              7  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...
# 9              6  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...
# 10             6  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...
# 11             5  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...
# 12             5  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...
# 13             5  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...
# 14             5  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...
# 15             5  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...
# 16             4  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...
# 17             4     [HG-U133A] Affymetrix Human Genome U133A Array
# 18             4  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...
# 19             4  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...

# %%
success_gse = set()

# %% [markdown]
# #### TASKS ####
#
# -- FAIL POINTS --
#     - GSE2215
# ------------------
# 1. Check if superseries
#     - Check for GSE redundancies?
#
# 2. Check data
#     - better way to drop na's...
#     - NOT SURE WHAT TO DO...
#         - GSE58173
#             - has '-inf' values...
#
# 3. Check normalization
#     - What are the differences between microarray normalization types?
#     - NOT SURE WHAT TO DO...
#         - GSE38021
#         - GSE34205
#         - GSE40281
# 4. Check Scale?
#     - NOT SURE WHAT TO DO...
#         - GSE34205
#     - After some log2 scaling there are negative values...
#
# 5. Convert gene names
#     - NOT SURE WHAT TO DO...
#         - GSE14390
#     - What's the best option for gene names?
#     - For microarray, how to handle replicate gene names?
#         - taking the average of log scaled replicate gene symbols seems like a bad idea...
#     - Pretty slow as currently written...
#
# 6. Upload checkpoints
#     - No negatives?
#     - No duplicates gene names
#     - drop NAs
#     - Unique GSE name
#     - Decent merge

# %%
# logfile = open('microarray_log.txt','w')

# %%
with open('picklejar/success_gse.pckl', 'rb') as picklefile:
    success_gse = pickle.load(picklefile)

# %%
# STOPPED HERE, GSE1133
# logfile = open('microarray_log.txt','a')

# %%
successCounter = 0
engine = create_engine('mysql+mysqlconnector://Simon:Bane@localhost/microarray_data')
logfile = open('microarray_log.txt','a')

for gse_acc in gse_training['gse'][166:]:
    if gse_acc in success_gse:
        continue
    stopToken = 0
    print('working on '+gse_acc+'\n')
    logNewGSE(logfile, gse_acc)
    
    try:
        gse = GEOparse.get_GEO(gse_acc)
    except:
        logfile.write('SKIPPED: too large')
        continue
    gse_meta = gse_training[gse_training['gse']==gse_acc]
    
    cds, gse_meta, stopToken = checkData(gse, gse_meta, sampleMeta, stopToken, logfile)
    if stopToken == 1:
        clean_tmp_files()
        continue
    
    #check scale
    cds, stopToken = checkScale(gse, cds, stopToken, logfile)
    if stopToken == 1:
        clean_tmp_files()
        continue
        
    #check normalization
    gse_norm = getNormalization(gse, cds, logfile)
    
    #convert gene names
    cds, stopToken = getGeneNames(gse, cds, gse_meta, stopToken, logfile)
    if stopToken == 1:
        clean_tmp_files()
        continue
    
    #format
    cds.rename(columns=lambda x: 'GSE_'+gse_acc+'__GSM_'+x+'__NORM_'+gse_norm, inplace = True)
    
    print(cds.head())
    
    #write to database
    stopToken = writeDataToSQL(cds, sampleMeta, gse_acc, stopToken, logfile)
    if stopToken == 1:
        clean_tmp_files()
        continue
    
    clean_tmp_files()
    success_gse.add(gse_acc)
    successCounter += 1

print(successCounter)
logfile.close()
# Out:
# 13-Aug-2019 14:27:20 DEBUG utils - Directory ./ already exists. Skipping.
# 13-Aug-2019 14:27:20 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE42nnn/GSE42926/soft/GSE42926_family.soft.gz to ./GSE42926_family.soft.gz
# 13-Aug-2019 14:27:20 INFO utils - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE42nnn/GSE42926/soft/GSE42926_family.soft.gz to ./GSE42926_family.soft.gz
# working on GSE42926
#
#  100 % [============================================================>]  25.2MiB / 25.2MiB    2.6MiB/s  eta 0:00:00
# 13-Aug-2019 14:27:30 INFO GEOparse - Parsing ./GSE42926_family.soft.gz:
# 13-Aug-2019 14:27:30 DEBUG GEOparse - DATABASE: GeoMiame
# 13-Aug-2019 14:27:30 DEBUG GEOparse - SERIES: GSE42926
# 13-Aug-2019 14:27:30 DEBUG GEOparse - PLATFORM: GPL570
# C:\ProgramData\Anaconda3\lib\site-packages\GEOparse\GEOparse.py:84: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   return parse_GSE(filepath)
# 13-Aug-2019 14:27:35 DEBUG GEOparse - SAMPLE: GSM1053463
# 13-Aug-2019 14:27:36 DEBUG GEOparse - SAMPLE: GSM1053464
# 13-Aug-2019 14:27:36 DEBUG GEOparse - SAMPLE: GSM1053465
# 13-Aug-2019 14:27:36 DEBUG GEOparse - SAMPLE: GSM1053466
# 13-Aug-2019 14:27:37 DEBUG GEOparse - SAMPLE: GSM1053467
# 13-Aug-2019 14:27:37 DEBUG GEOparse - SAMPLE: GSM1053468
# 13-Aug-2019 14:27:37 DEBUG GEOparse - SAMPLE: GSM1053469
# 13-Aug-2019 14:27:38 DEBUG GEOparse - SAMPLE: GSM1053470
# 13-Aug-2019 14:27:38 DEBUG GEOparse - SAMPLE: GSM1053471
# 13-Aug-2019 14:27:39 DEBUG GEOparse - SAMPLE: GSM1053472
# 13-Aug-2019 14:27:39 DEBUG GEOparse - SAMPLE: GSM1053473
# 13-Aug-2019 14:27:39 DEBUG GEOparse - SAMPLE: GSM1053474
# 13-Aug-2019 14:27:40 DEBUG GEOparse - SAMPLE: GSM1053475
# 13-Aug-2019 14:27:40 DEBUG GEOparse - SAMPLE: GSM1053476
# 13-Aug-2019 14:27:40 DEBUG GEOparse - SAMPLE: GSM1053477
# 13-Aug-2019 14:27:41 DEBUG GEOparse - SAMPLE: GSM1053478
# 13-Aug-2019 14:27:41 DEBUG GEOparse - SAMPLE: GSM1053479
# 13-Aug-2019 14:27:41 DEBUG GEOparse - SAMPLE: GSM1053480
# 13-Aug-2019 14:27:42 DEBUG GEOparse - SAMPLE: GSM1053481
# 13-Aug-2019 14:27:42 DEBUG GEOparse - SAMPLE: GSM1053482
# 13-Aug-2019 14:27:42 DEBUG GEOparse - SAMPLE: GSM1053483
# 13-Aug-2019 14:28:18 DEBUG GEOparse - SAMPLE: GSM1060777
# 13-Aug-2019 14:28:18 DEBUG GEOparse - SAMPLE: GSM1060778
# 13-Aug-2019 14:28:18 DEBUG GEOparse - SAMPLE: GSM1060779
# 13-Aug-2019 14:28:18 DEBUG GEOparse - SAMPLE: GSM1060780
# 13-Aug-2019 14:28:19 DEBUG GEOparse - SAMPLE: GSM1060781
# 13-Aug-2019 14:28:19 DEBUG GEOparse - SAMPLE: GSM1060782
# 13-Aug-2019 14:28:19 DEBUG GEOparse - SAMPLE: GSM1060783
# 13-Aug-2019 14:28:19 DEBUG GEOparse - SAMPLE: GSM1060784
# 13-Aug-2019 14:28:19 DEBUG GEOparse - SAMPLE: GSM1060785
# 13-Aug-2019 14:28:19 DEBUG GEOparse - SAMPLE: GSM1060786
# 13-Aug-2019 14:28:20 DEBUG GEOparse - SAMPLE: GSM1060787
# 13-Aug-2019 14:28:20 DEBUG GEOparse - SAMPLE: GSM1060788
# 13-Aug-2019 14:28:20 DEBUG GEOparse - SAMPLE: GSM1060789
# 13-Aug-2019 14:28:20 DEBUG GEOparse - SAMPLE: GSM1060790
# 13-Aug-2019 14:28:20 DEBUG GEOparse - SAMPLE: GSM1060791
# 13-Aug-2019 14:28:20 DEBUG GEOparse - SAMPLE: GSM1060792
# 13-Aug-2019 14:28:20 DEBUG GEOparse - SAMPLE: GSM1060793
# 13-Aug-2019 14:28:21 DEBUG GEOparse - SAMPLE: GSM1060794
# 13-Aug-2019 14:28:21 DEBUG GEOparse - SAMPLE: GSM1060795
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\ProgramData\Anaconda3\lib\site-packages\GEOparse\GEOTypes.py:794: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   ndf = concat(data).pivot(index=index, values=values, columns="name")
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: divide by zero encountered in log2
# name             GSE_GSE43346__GSM_GSM1060761__NORM_MAS5  \
# gene_symbol_sql
# A1BG                                            6.131343
# A1BG-AS1                                        1.925999
# A1CF                                            2.274218
# A2M                                             8.526634
# A2M-AS1                                         3.935460
#
# name             GSE_GSE43346__GSM_GSM1060760__NORM_MAS5
# gene_symbol_sql
# A1BG                                            5.232661
# A1BG-AS1                                        3.797013
# A1CF                                            2.947409
# A2M                                             4.341287
# A2M-AS1                                         0.678072
# 13-Aug-2019 14:29:42 DEBUG utils - Directory ./ already exists. Skipping.
# 13-Aug-2019 14:29:42 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE43nnn/GSE43769/soft/GSE43769_family.soft.gz to ./GSE43769_family.soft.gz
# 13-Aug-2019 14:29:42 INFO utils - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE43nnn/GSE43769/soft/GSE43769_family.soft.gz to ./GSE43769_family.soft.gz
# working on GSE43769
#
#  100 % [============================================================>]  15.0MiB / 15.0MiB    3.7MiB/s  eta 0:00:01
# 13-Aug-2019 14:29:47 INFO GEOparse - Parsing ./GSE43769_family.soft.gz:
# 13-Aug-2019 14:29:47 DEBUG GEOparse - DATABASE: GeoMiame
# 13-Aug-2019 14:29:47 DEBUG GEOparse - SERIES: GSE43769
# 13-Aug-2019 14:29:47 DEBUG GEOparse - PLATFORM: GPL570
# 13-Aug-2019 14:29:50 DEBUG GEOparse - SAMPLE: GSM1070753
# 13-Aug-2019 14:29:51 DEBUG GEOparse - SAMPLE: GSM1070754
NORM_RMA  \
# gene_symbol_sql
# A1BG                                           6.423280
# A1BG-AS1                                       6.803550
# A1CF                                           3.929120
# A2M                                            4.866895
# A2M-AS1                                        3.314810
#
# name             GSE_GSE43769__GSM_GSM1070761__NORM_RMA
# gene_symbol_sql
# A1BG                                           7.021550
# A1BG-AS1                                       6.912130
# A1CF                                           3.860655
# A2M                                            4.904735
# A2M-AS1                                        3.636450
# 13-Aug-2019 14:29:59 DEBUG utils - Directory ./ already exists. Skipping.
# 13-Aug-2019 14:29:59 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE44nnn/GSE44126/soft/GSE44126_family.soft.gz to ./GSE44126_family.soft.gz
# 13-Aug-2019 14:29:59 INFO utils - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE44nnn/GSE44126/soft/GSE44126_family.soft.gz to ./GSE44126_family.soft.gz
# working on GSE44126
#
#  100 % [============================================================>]  17.7MiB / 17.7MiB    3.5MiB/s  eta 0:00:00
# 13-Aug-2019 14:30:05 INFO GEOparse - Parsing ./GSE44126_family.soft.gz:
# 13-Aug-2019 14:30:05 DEBUG GEOparse - DATABASE: GeoMiame
# 13-Aug-2019 14:30:05 DEBUG GEOparse - SERIES: GSE44126
# 13-Aug-2019 14:30:05 DEBUG GEOparse - PLATFORM: GPL570
# 13-Aug-2019 14:30:08 DEBUG GEOparse - SAMPLE: GSM1079344
# 13-Aug-2019 14:30:08 DEBUG GEOparse - SAMPLE: GSM1079345
# 13-Aug-2019 14:30:08 DEBUG GEOparse - SAMPLE: GSM1079346
# 13-Aug-2019 14:30:08 DEBUG GEOparse - SAMPLE: GSM1079347
# 13-Aug-2019 14:30:09 DEBUG GEOparse - SAMPLE: GSM1079348
# 13-Aug-2019 14:30:09 DEBUG GEOparse - SAMPLE: GSM1079349
# 13-Aug-2019 14:30:09 DEBUG GEOparse - SAMPLE: GSM1079350
# 13-Aug-2019 14:30:09 DEBUG GEOparse - SAMPLE: GSM1079351
# 13-Aug-2019 14:30:10 DEBUG GEOparse - SAMPLE: GSM1079352
# 13-Aug-2019 14:30:10 DEBUG GEOparse - SAMPLE: GSM1079353
# 13-Aug-2019 14:30:10 DEBUG GEOparse - SAMPLE: GSM1079354
# 13-Aug-2019 14:30:10 DEBUG GEOparse - SAMPLE: GSM1079355
# 13-Aug-2019 14:30:10 DEBUG GEOparse - SAMPLE: GSM1079356
# 13-Aug-2019 14:30:10 DEBUG GEOparse - SAMPLE: GSM1079357
# 13-Aug-2019 14:30:10 DEBUG GEOparse - SAMPLE: GSM1079358
# name             GSE_GSE44126__GSM_GSM1079356__NORM_unknown  \
# gene_symbol_sql
# A1BG                                               4.998845
# A1BG-AS1                                           4.475304
# A1CF                                               3.276672
# A2M                                                3.159019
# A2M-AS1                                            2.701968
#
# name             GSE_GSE44126__GSM_GSM1079354__NORM_unknown  \
# gene_symbol_sql
# A1BG                                               4.652401
# A1BG-AS1                                           4.528967
# A1CF                                               3.244787
# A2M                                                3.311350
# A2M-AS1                                            2.815809
#
# name             GSE_GSE44126__GSM_GSM1079355__NORM_unknown  \
# gene_symbol_sql
# A1BG                                               5.076389
# A1BG-AS1                                           4.147674
# A1CF                                               3.306874
# A2M                                                3.276752
# A2M-AS1                                            2.879693
#
# name             GSE_GSE44126__GSM_GSM1079347__NORM_unknown  \
# gene_symbol_sql
# A1BG                                               5.152847
# A1BG-AS1                                           4.562141
# A1CF                                               3.391247
# A2M                                                3.325397
# A2M-AS1                                            2.494616
#
# name             GSE_GSE44126__GSM_GSM1079352__NORM_unknown  \
# gene_symbol_sql
# A1BG                                               5.178916
# A1BG-AS1                                           4.475304
# A1CF                                               3.307987
# A2M                                                3.120016
# A2M-AS1                                            2.815809
#
# name             GSE_GSE44126__GSM_GSM1079357__NORM_unknown  \
# gene_symbol_sql
# A1BG                                               5.303058
# A1BG-AS1                                           4.806201
# A1CF                                               3.383546
# A2M                                                3.048112
# A2M-AS1                                            3.246701
#
# name             GSE_GSE44126__GSM_GSM1079348__NORM_unknown  \
# gene_symbol_sql
# A1BG                                               4.615139
# A1BG-AS1                                           4.520326
# A1CF                                               3.188990
# A2M                                                3.069355
# A2M-AS1                                            2.475874
#
# name             GSE_GSE44126__GSM_GSM1079353__NORM_unknown  \
# gene_symbol_sql
# A1BG                                               4.867523
# A1BG-AS1                                           4.468640
# A1CF                                               3.292561
# A2M                                                3.186482
# A2M-AS1                                            3.134622
#
# name             GSE_GSE44126__GSM_GSM1079358__NORM_unknown  \
# gene_symbol_sql
# A1BG                                               4.940582
# A1BG-AS1                                           4.558342
# A1CF                                               3.484317
# A2M                                                3.182636
# A2M-AS1                                            3.644796
#
# name             GSE_GSE44126__GSM_GSM1079345__NORM_unknown  \
# gene_symbol_sql
# A1BG                                               4.832954
# A1BG-AS1                                           4.741608
# A1CF                                               3.478847
# A2M                                                3.355373
# A2M-AS1                                            2.869882
#
# name             GSE_GSE44126__GSM_GSM1079350__NORM_unknown  \
# gene_symbol_sql
# A1BG                                               5.109535
# A1BG-AS1                                           4.543519
# A1CF                                               3.523861
# A2M                                                3.114637
# A2M-AS1                                            3.087978
#
# name             GSE_GSE44126__GSM_GSM1079344__NORM_unknown  \
# gene_symbol_sql
# A1BG                                               4.910806
# A1BG-AS1                                           4.620838
# A1CF                                               3.292263
# A2M                                                3.165798
# A2M-AS1                                            2.661320
#
# name             GSE_GSE44126__GSM_GSM1079351__NORM_unknown  \
# gene_symbol_sql
# A1BG                                               4.965819
# A1BG-AS1                                           4.611086
# A1CF                                               3.345209
# A2M                                                3.136670
# A2M-AS1                                            2.852792
#
# name             GSE_GSE44126__GSM_GSM1079346__NORM_unknown  \
# gene_symbol_sql
# A1BG                                               4.791428
# A1BG-AS1                                           4.806987
# A1CF                                               3.268604
# A2M                                                3.194362
# A2M-AS1                                            2.441053
#
# name             GSE_GSE44126__GSM_GSM1079349__NORM_unknown
# gene_symbol_sql
# A1BG                                               4.936190
# A1BG-AS1                                           4.569547
# A1CF                                               3.421096
# A2M                                                3.266634
# A2M-AS1                                            2.947971
# 13-Aug-2019 14:31:07 DEBUG utils - Directory ./ already exists. Skipping.
# 13-Aug-2019 14:31:07 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE44nnn/GSE44164/soft/GSE44164_family.soft.gz to ./GSE44164_family.soft.gz
# 13-Aug-2019 14:31:07 INFO utils - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE44nnn/GSE44164/soft/GSE44164_family.soft.gz to ./GSE44164_family.soft.gz
# working on GSE44164
#
#  100 % [============================================================>]  11.7MiB / 11.7MiB    3.5MiB/s  eta 0:00:00
# 13-Aug-2019 14:31:11 INFO GEOparse - Parsing ./GSE44164_family.soft.gz:
# 13-Aug-2019 14:31:11 DEBUG GEOparse - DATABASE: GeoMiame
# 13-Aug-2019 14:31:11 DEBUG GEOparse - SERIES: GSE44164
# 13-Aug-2019 14:31:11 DEBUG GEOparse - PLATFORM: GPL96
# 13-Aug-2019 14:31:13 DEBUG GEOparse - SAMPLE: GSM1079833
# 13-Aug-2019 14:31:13 DEBUG GEOparse - SAMPLE: GSM1079834
# 13-Aug-2019 14:31:13 DEBUG GEOparse - SAMPLE: GSM1079835
# 13-Aug-2019 14:31:13 DEBUG GEOparse - SAMPLE: GSM1079836
# 13-Aug-2019 14:31:13 DEBUG GEOparse - SAMPLE: GSM1079837
# 13-Aug-2019 14:31:13 DEBUG GEOparse - SAMPLE: GSM1079838
# 13-Aug-2019 14:31:13 DEBUG GEOparse - SAMPLE: GSM1079839
# 13-Aug-2019 14:31:14 DEBUG GEOparse - SAMPLE: GSM1079840
# 13-Aug-2019 14:31:14 DEBUG GEOparse - SAMPLE: GSM1079841
# 13-Aug-2019 14:31:14 DEBUG GEOparse - SAMPLE: GSM1079842
# 13-Aug-2019 14:31:14 DEBUG GEOparse - SAMPLE: GSM1079843
# 13-Aug-2019 14:31:14 DEBUG GEOparse - SAMPLE: GSM1079844
# 13-Aug-2019 14:31:14 DEBUG GEOparse - SAMPLE: GSM1079845
# 13-Aug-2019 14:31:14 DEBUG GEOparse - SAMPLE: GSM1079846
# 13-Aug-2019 14:31:14 DEBUG GEOparse - SAMPLE: GSM1079847
# 13-Aug-2019 14:31:14 DEBUG GEOparse - SAMPLE: GSM1079848
# 13-Aug-2019 14:31:14 DEBUG GEOparse - SAMPLE: GSM1079849
# 13-Aug-2019 14:31:14 DEBUG GEOparse - SAMPLE: GSM1079850
# 13-Aug-2019 14:31:15 DEBUG GEOparse - SAMPLE: GSM1079851
# 13-Aug-2019 14:31:15 DEBUG GEOparse - SAMPLE: GSM1079852
# 13-Aug-2019 14:31:15 DEBUG GEOparse - SAMPLE: GSM1079853
# 13-Aug-2019 14:31:15 DEBUG GEOparse - SAMPLE: GSM1079854
# 13-Aug-2019 14:31:15 DEBUG GEOparse - SAMPLE: GSM1079855
# 13-Aug-2019 14:31:15 DEBUG GEOparse - SAMPLE: GSM1079856
# 13-Aug-2019 14:31:15 DEBUG GEOparse - SAMPLE: GSM1079857
# 13-Aug-2019 14:31:15 DEBUG GEOparse - SAMPLE: GSM1079858
# 13-Aug-2019 14:31:15 DEBUG GEOparse - SAMPLE: GSM1079859
# 13-Aug-2019 14:31:15 DEBUG GEOparse - SAMPLE: GSM1079860
# 13-Aug-2019 14:31:15 DEBUG GEOparse - SAMPLE: GSM1079861
# 13-Aug-2019 14:31:15 DEBUG GEOparse - SAMPLE: GSM1079862
# 13-Aug-2019 14:31:15 DEBUG GEOparse - SAMPLE: GSM1079863
# 13-Aug-2019 14:31:15 DEBUG GEOparse - SAMPLE: GSM1079864
# name             GSE_GSE44164__GSM_GSM1079862__NORM_unknown  \
# gene_symbol_sql
# A1CF                                               8.039581
# A2M                                                9.891257
# A4GALT                                             7.702398
# A4GNT                                              8.102608
# AAAS                                               8.922063
#
# name             GSE_GSE44164__GSM_GSM1079858__NORM_unknown  \
# gene_symbol_sql
# A1CF                                               8.322417
# A2M                                               10.976107
# A4GALT                                             7.223660
# A4GNT                                              8.083135
# AAAS                                               8.705784
#
# name             GSE_GSE44164__GSM_GSM1079843__NORM_unknown  \
# gene_symbol_sql
# A1CF                                               8.032337
# A2M                                                9.728427
# A4GALT                                             7.860678
# A4GNT                                              8.177431
# AAAS                                               9.322767
#
# name             GSE_GSE44164__GSM_GSM1079860__NORM_unknown  \
# gene_symbol_sql
# A1CF                                               8.175222
# A2M                                                9.749624
# A4GALT                                             7.754019
# A4GNT                                              7.902740
# AAAS                                               8.822073
#
# name             GSE_GSE44164__GSM_GSM1079851__NORM_unknown  \
# gene_symbol_sql
# A1CF                                               8.183559
# A2M                                               10.147468
# A4GALT                                             7.493376
# A4GNT                                              8.179587
# AAAS                                               8.689622
#
# name             GSE_GSE44164__GSM_GSM1079855__NORM_unknown  \
# gene_symbol_sql
# A1CF                                               8.001823
# A2M                                                9.545350
# A4GALT                                             7.271323
# A4GNT                                              8.115560
# AAAS                                               8.803840
#
# name             GSE_GSE44164__GSM_GSM1079857__NORM_unknown  \
# gene_symbol_sql
# A1CF                                               8.161651
# A2M                                                9.907383
# A4GALT                                             7.341467
# A4GNT                                              8.023419
# AAAS                                               8.681780
#
# name             GSE_GSE44164__GSM_GSM1079837__NORM_unknown  \
# gene_symbol_sql
# A1CF                                               7.847743
# A2M                                                9.626374
# A4GALT                                             8.016062
# A4GNT                                              7.880767
# AAAS                                               8.886006
#
# name             GSE_GSE44164__GSM_GSM1079839__NORM_unknown  \
# gene_symbol_sql
# A1CF                                               8.037288
# A2M                                               10.502949
# A4GALT                                             7.972195
# A4GNT                                              8.084426
# AAAS                                               8.730035
#
# name             GSE_GSE44164__GSM_GSM1079840__NORM_unknown  ...  \
# gene_symbol_sql                                              ...
# A1CF                                               7.942976  ...
# A2M                                               10.108257  ...
# A4GALT                                             7.824050  ...
# A4GNT                                              8.012659  ...
# AAAS                                               9.067808  ...
#
# name             GSE_GSE44164__GSM_GSM1079833__NORM_unknown  \
# gene_symbol_sql
# A1CF                                               8.065055
# A2M                                               10.330284
# A4GALT                                             7.445673
# A4GNT                                              7.936143
# AAAS                                               8.959983
#
# name             GSE_GSE44164__GSM_GSM1079834__NORM_unknown  \
# gene_symbol_sql
# A1CF                                               8.149337
# A2M                                               10.145281
# A4GALT                                             7.680756
# A4GNT                                              7.984067
# AAAS                                               8.839095
#
# name             GSE_GSE44164__GSM_GSM1079848__NORM_unknown  \
# gene_symbol_sql
# A1CF                                               8.253609
# A2M                                                9.528569
# A4GALT                                             7.931159
# A4GNT                                              8.061620
# AAAS                                               9.069383
#
# name             GSE_GSE44164__GSM_GSM1079853__NORM_unknown  \
# gene_symbol_sql
# A1CF                                               7.968136
# A2M                                                9.500570
# A4GALT                                             7.312446
# A4GNT                                              8.114679
# AAAS                                               8.482222
#
# name             GSE_GSE44164__GSM_GSM1079864__NORM_unknown  \
# gene_symbol_sql
# A1CF                                               7.957883
# A2M                                               10.751388
# A4GALT                                             7.552713
# A4GNT                                              7.807283
# AAAS                                               8.813706
#
# name             GSE_GSE44164__GSM_GSM1079836__NORM_unknown  \
# gene_symbol_sql
# A1CF                                               8.118309
# A2M                                               10.394565
# A4GALT                                             7.762030
# A4GNT                                              8.098388
# AAAS                                               9.134602
#
# name             GSE_GSE44164__GSM_GSM1079838__NORM_unknown  \
# gene_symbol_sql
# A1CF                                               8.017841
# A2M                                                9.826489
# A4GALT                                             8.159523
# A4GNT                                              7.874796
# AAAS                                               9.159242
#
# name             GSE_GSE44164__GSM_GSM1079847__NORM_unknown  \
# gene_symbol_sql
# A1CF                                               7.965241
# A2M                                                9.869747
# A4GALT                                             7.800294
# A4GNT                                              7.915163
# AAAS                                               9.134106
#
# name             GSE_GSE44164__GSM_GSM1079849__NORM_unknown  \
# gene_symbol_sql
# A1CF                                               8.129457
# A2M                                                9.503906
# A4GALT                                             7.608764
# A4GNT                                              8.005975
# AAAS                                               8.919347
#
# name             GSE_GSE44164__GSM_GSM1079859__NORM_unknown
# gene_symbol_sql
# A1CF                                               7.990524
# A2M                                                9.766340
# A4GALT                                             7.568444
# A4GNT                                              8.088872
# AAAS                                               8.840818
#
# [5 rows x 32 columns]
# 13-Aug-2019 14:33:22 DEBUG utils - Directory ./ already exists. Skipping.
# 13-Aug-2019 14:33:22 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE44nnn/GSE44732/soft/GSE44732_family.soft.gz to ./GSE44732_family.soft.gz
# 13-Aug-2019 14:33:22 INFO utils - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE44nnn/GSE44732/soft/GSE44732_family.soft.gz to ./GSE44732_family.soft.gz
# working on GSE44732
#
#  100 % [============================================================>]  12.5MiB / 12.5MiB    3.3MiB/s  eta 0:00:00
# 13-Aug-2019 14:33:26 INFO GEOparse - Parsing ./GSE44732_family.soft.gz:
# 13-Aug-2019 14:33:26 DEBUG GEOparse - DATABASE: GeoMiame
# 13-Aug-2019 14:33:26 DEBUG GEOparse - SERIES: GSE44732
# 13-Aug-2019 14:33:26 DEBUG GEOparse - PLATFORM: GPL6244
# 13-Aug-2019 14:33:29 DEBUG GEOparse - SAMPLE: GSM1089787
# 13-Aug-2019 14:33:29 DEBUG GEOparse - SAMPLE: GSM1089788
# 13-Aug-2019 14:33:29 DEBUG GEOparse - SAMPLE: GSM1089789
# 13-Aug-2019 14:33:29 DEBUG GEOparse - SAMPLE: GSM1089790
# 13-Aug-2019 14:33:29 DEBUG GEOparse - SAMPLE: GSM1089791
# 13-Aug-2019 14:33:29 DEBUG GEOparse - SAMPLE: GSM1089792
# 13-Aug-2019 14:33:30 DEBUG utils - Directory ./ already exists. Skipping.
# 13-Aug-2019 14:33:30 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE4nnn/GSE4475/soft/GSE4475_family.soft.gz to ./GSE4475_family.soft.gz
# 13-Aug-2019 14:33:30 INFO utils - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE4nnn/GSE4475/soft/GSE4475_family.soft.gz to ./GSE4475_family.soft.gz
# working on GSE4475
#
#   98 % [===========================================================> ]  57.7MiB / 58.5MiB    3.1MiB/s  eta 0:00:00
# 13-Aug-2019 14:33:52 DEBUG GEOparse - SAMPLE: GSM100477
# 13-Aug-2019 14:33:52 DEBUG GEOparse - SAMPLE: GSM100478
# 13-Aug-2019 14:33:52 DEBUG GEOparse - SAMPLE: GSM100479
NORM_RMA  \
# gene_symbol_sql
# A1BG                                           5.428712
# A1BG-AS1                                       3.979557
# A1CF                                           2.546383
# A2M                                            2.862301
# A2M-AS1                                        5.121165
#
# name             GSE_GSE65010__GSM_GSM1585753__NORM_RMA  \
# gene_symbol_sql
# A1BG                                           5.506894
# A1BG-AS1                                       3.993039
# A1CF                                           2.592868
# A2M                                            2.972334
# A2M-AS1                                        4.515412
#
# name             GSE_GSE65010__GSM_GSM1585775__NORM_RMA  \
# gene_symbol_sql
# A1BG                                           4.635109
# A1BG-AS1                                       3.627168
# A1CF                                           2.796145
# A2M                                            3.018015
# A2M-AS1                                        3.086142
#
# name             GSE_GSE65010__GSM_GSM1585764__NORM_RMA
# gene_symbol_sql
# A1BG                                           5.782462
# A1BG-AS1                                       3.811027
# A1CF                                           2.580646
# A2M                                            2.729555
# A2M-AS1                                        4.613986
#
# [5 rows x 36 columns]
# 13-Aug-2019 15:25:53 DEBUG utils - Directory ./ already exists. Skipping.
# 13-Aug-2019 15:25:53 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE65nnn/GSE65856/soft/GSE65856_family.soft.gz to ./GSE65856_family.soft.gz
# 13-Aug-2019 15:25:53 INFO utils - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE65nnn/GSE65856/soft/GSE65856_family.soft.gz to ./GSE65856_family.soft.gz
# working on GSE65856
#
#  100 % [============================================================>]  17.9MiB / 17.9MiB    3.7MiB/s  eta 0:00:00
# 13-Aug-2019 15:25:58 INFO GEOparse - Parsing ./GSE65856_family.soft.gz:
# 13-Aug-2019 15:25:58 DEBUG GEOparse - DATABASE: GeoMiame
# 13-Aug-2019 15:25:58 DEBUG GEOparse - SERIES: GSE65856
# 13-Aug-2019 15:25:58 DEBUG GEOparse - PLATFORM: GPL570
# 13-Aug-2019 15:26:03 DEBUG GEOparse - SAMPLE: GSM1607651
# 13-Aug-2019 15:26:03 DEBUG GEOparse - SAMPLE: GSM1607652
# 13-Aug-2019 15:26:04 DEBUG GEOparse - SAMPLE: GSM1607653
# 13-Aug-2019 15:26:04 DEBUG GEOparse - SAMPLE: GSM1607654
# 13-Aug-2019 15:26:04 DEBUG GEOparse - SAMPLE: GSM1607655
# 13-Aug-2019 15:26:04 DEBUG GEOparse - SAMPLE: GSM1607656
# 13-Aug-2019 15:26:04 DEBUG GEOparse - SAMPLE: GSM1607657
# 13-Aug-2019 15:26:05 DEBUG GEOparse - SAMPLE: GSM1607658
# 13-Aug-2019 15:26:05 DEBUG GEOparse - SAMPLE: GSM1607659
# 13-Aug-2019 15:26:05 DEBUG GEOparse - SAMPLE: GSM1607660
# 13-Aug-2019 15:26:05 DEBUG GEOparse - SAMPLE: GSM1607661
# 13-Aug-2019 15:26:05 DEBUG GEOparse - SAMPLE: GSM1607662
# 13-Aug-2019 15:26:06 DEBUG GEOparse - SAMPLE: GSM1607663
# 13-Aug-2019 15:26:06 DEBUG GEOparse - SAMPLE: GSM1607664
# 13-Aug-2019 15:26:06 DEBUG GEOparse - SAMPLE: GSM1607665
# name             GSE_GSE65856__GSM_GSM1607656__NORM_MAS5  \
# gene_symbol_sql
# A1BG                                            5.510842
# A1BG-AS1                                        4.737021
# A1CF                                            4.061649
# A2M                                             3.034952
# A2M-AS1                                         3.714191
#
# name             GSE_GSE65856__GSM_GSM1607655__NORM_MAS5  \
# gene_symbol_sql
# A1BG                                            5.929647
# A1BG-AS1                                        4.258707
# A1CF                                            2.537754
# A2M                                             1.266626
# A2M-AS1                                         2.324546
#
# name             GSE_GSE65856__GSM_GSM1607651__NORM_MAS5  \
# gene_symbol_sql
# A1BG                                            5.788352
# A1BG-AS1                                        5.256316
# A1CF                                            4.096989
# A2M                                             3.818765
# A2M-AS1                                         3.452213
#
# name             GSE_GSE65856__GSM_GSM1607654__NORM_MAS5  \
# gene_symbol_sql
# A1BG                                            5.571774
# A1BG-AS1                                        3.325847
# A1CF                                            1.935955
# A2M                                             1.946984
# A2M-AS1                                         3.652659
#
# name             GSE_GSE65856__GSM_GSM1607652__NORM_MAS5  \
# gene_symbol_sql
# A1BG                                            5.631439
# A1BG-AS1                                        4.432492
# A1CF                                            3.570901
# A2M                                             2.053434
# A2M-AS1                                         3.472813
#
# name             GSE_GSE65856__GSM_GSM1607660__NORM_MAS5  \
# gene_symbol_sql
# A1BG                                            5.551356
# A1BG-AS1                                        4.274045
# A1CF                                            3.292879
# A2M                                             3.521135
# A2M-AS1                                         3.636532
#
# name             GSE_GSE65856__GSM_GSM1607653__NORM_MAS5  \
# gene_symbol_sql
# A1BG                                            5.429465
# A1BG-AS1                                        1.785040
# A1CF                                            2.977232
# A2M                                             3.002474
# A2M-AS1                                         2.725774
#
# name             GSE_GSE65856__GSM_GSM1607665__NORM_MAS5  \
# gene_symbol_sql
# A1BG                                            5.950006
# A1BG-AS1                                        4.613443
# A1CF                                            3.264057
# A2M                                             1.799722
# A2M-AS1                                         4.026782
#
# name             GSE_GSE65856__GSM_GSM1607664__NORM_MAS5  \
# gene_symbol_sql
# A1BG                                            5.825376
# A1BG-AS1                                        4.318519
# A1CF                                            3.510199
# A2M                                             3.301704
# A2M-AS1                                         1.980007
#
# name             GSE_GSE65856__GSM_GSM1607658__NORM_MAS5  \
# gene_symbol_sql
# A1BG                                            5.651195
# A1BG-AS1                                        4.981387
# A1CF                                            3.671100
# A2M                                             2.476427
# A2M-AS1                                         3.249342
#
# name             GSE_GSE65856__GSM_GSM1607662__NORM_MAS5  \
# gene_symbol_sql
# A1BG                                            5.408987
# A1BG-AS1                                        4.571847
# A1CF                                            3.349548
# A2M                                             3.905154
# A2M-AS1                                         2.974843
#
# name             GSE_GSE65856__GSM_GSM1607657__NORM_MAS5  \
# gene_symbol_sql
# A1BG                                            5.152463
# A1BG-AS1                                        4.658194
# A1CF                                            2.554647
# A2M                                             3.152159
# A2M-AS1                                         3.136121
#
# name             GSE_GSE65856__GSM_GSM1607663__NORM_MAS5  \
# gene_symbol_sql
# A1BG                                            6.042095
# A1BG-AS1                                        3.585780
# A1CF                                            2.240964
# A2M                                             3.150345
# A2M-AS1                                         2.966436
#
# name             GSE_GSE65856__GSM_GSM1607659__NORM_MAS5  \
# gene_symbol_sql
# A1BG                                            5.851604
# A1BG-AS1                                        3.083064
# A1CF                                            3.585884
# A2M                                             2.574740
# A2M-AS1                                         3.379926
#
# name             GSE_GSE65856__GSM_GSM1607661__NORM_MAS5
# gene_symbol_sql
# A1BG                                            5.637825
# A1BG-AS1                                        4.131318
# A1CF                                            1.872814
# A2M                                             2.070298
# A2M-AS1                                         2.928463
# 13-Aug-2019 15:27:41 DEBUG utils - Directory ./ already exists. Skipping.
# 13-Aug-2019 15:27:41 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE65nnn/GSE65928/soft/GSE65928_family.soft.gz to ./GSE65928_family.soft.gz
# 13-Aug-2019 15:27:41 INFO utils - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GS
# 13-Aug-2019 15:27:54 DEBUG GEOparse - SAMPLE: GSM1611311
# 13-Aug-2019 15:27:54 DEBUG GEOparse - SAMPLE: GSM1611312
# 13-Aug-2019 15:27:55 DEBUG GEOparse - SAMPLE: GSM1611313
# 13-Aug-2019 15:27:55 DEBUG GEOparse - SAMPLE: GSM1611314
# 13-Aug-2019 15:27:55 DEBUG GEOparse - SAMPLE: GSM1611315
# 13-Aug-2019 15:27:55 DEBUG GEOparse - SAMPLE: GSM1611316
# 13-Aug-2019 15:27:55 DEBUG GEOparse - SAMPLE: GSM1611317
# 13-Aug-2019 15:27:55 DEBUG GEOparse - SAMPLE: GSM1611318
# 13-Aug-2019 15:27:55 DEBUG GEOparse - SAMPLE: GSM1611319
# 13-Aug-2019 15:27:55 DEBUG GEOparse - SAMPLE: GSM1611320
# 13-Aug-2019 15:27:55 DEBUG GEOparse - SAMPLE: GSM1611321
# 13-Aug-2019 15:27:56 DEBUG GEOparse - SAMPLE: GSM1611322
# 13-Aug-2019 15:27:56 DEBUG GEOparse - SAMPLE: GSM1611323
# 13-Aug-2019 15:27:56 DEBUG GEOparse - SAMPLE: GSM1611324
# 13-Aug-2019 15:27:56 DEBUG GEOparse - SAMPLE: GSM1611325
# 13-Aug-2019 15:27:56 DEBUG GEOparse - SAMPLE: GSM1611326
# 13-Aug-2019 15:27:56 DEBUG GEOparse - SAMPLE: GSM1611327
# 13-Aug-2019 15:27:56 DEBUG GEOparse - SAMPLE: GSM1611328
# 13-Aug-2019 15:27:56 DEBUG GEOparse - SAMPLE: GSM1611329
# 13-Aug-2019 15:27:56 DEBUG GEOparse - SAMPLE: GSM1611330
# 13-Aug-2019 15:27:57 DEBUG GEOparse - SAMPLE: GSM1611331
# 13-Aug-2019 15:27:57 DEBUG GEOparse - SAMPLE: GSM1611332
# 13-Aug-2019 15:27:57 DEBUG GEOparse - SAMPLE: GSM1611333
# 13-Aug-2019 15:27:57 DEBUG GEOparse - SAMPLE: GSM1611334
# 13-Aug-2019 15:27:57 DEBUG GEOparse - SAMPLE: GSM1611335
# 13-Aug-2019 15:27:57 DEBUG GEOparse - SAMPLE: GSM1611336

# %%
np.where(gse_training['gse']=='GSE65928')
# gse_training['gse'][51:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cddf0c7caa37> in <module>
# ----> 1 np.where(gse_training['gse']=='GSE65928')
#       2 # gse_training['gse'][51:]
#
# NameError: name 'np' is not defined

# %%
with open('picklejar/success_gse.pckl', 'wb') as picklefile:
    pickle.dump(success_gse, picklefile)

# %%
# engine = create_engine('mysql+mysqlconnector://Simon:Bane@localhost/microarray_data')
clean_tmp_files()
logfile.close()

# %%
stopToken = 0
gse_acc = 'GSE11083'
gse = GEOparse.get_GEO(gse_acc)
gse_meta = gse_training[gse_training['gse']==gse_acc]
# Out:
# 13-Aug-2019 12:22:08 DEBUG utils - Directory ./ already exists. Skipping.
# 13-Aug-2019 12:22:08 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE11nnn/GSE11083/soft/GSE11083_family.soft.gz to ./GSE11083_family.soft.gz
# 13-Aug-2019 12:22:08 INFO utils - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GS
# 13-Aug-2019 12:22:52 DEBUG GEOparse - SAMPLE: GSM280003
# 13-Aug-2019 12:22:52 DEBUG GEOparse - SAMPLE: GSM280004
# 13-Aug-2019 12:22:52 DEBUG GEOparse - SAMPLE: GSM280006
# 13-Aug-2019 12:22:52 DEBUG GEOparse - SAMPLE: GSM280007
# 13-Aug-2019 12:22:53 DEBUG GEOparse - SAMPLE: GSM280008
# 13-Aug-2019 12:22:53 DEBUG GEOparse - SAMPLE: GSM280009
# 13-Aug-2019 12:22:53 DEBUG GEOparse - SAMPLE: GSM280010
# 13-Aug-2019 12:22:53 DEBUG GEOparse - SAMPLE: GSM280017
# 13-Aug-2019 12:22:54 DEBUG GEOparse - SAMPLE: GSM280018
# 13-Aug-2019 12:22:54 DEBUG GEOparse - SAMPLE: GSM280019
# 13-Aug-2019 12:22:54 DEBUG GEOparse - SAMPLE: GSM280020
# 13-Aug-2019 12:22:54 DEBUG GEOparse - SAMPLE: GSM280023
# 13-Aug-2019 12:22:54 DEBUG GEOparse - SAMPLE: GSM280025
# 13-Aug-2019 12:22:55 DEBUG GEOparse - SAMPLE: GSM280026
# 13-Aug-2019 12:22:55 DEBUG GEOparse - SAMPLE: GSM280027
# 13-Aug-2019 12:22:55 DEBUG GEOparse - SAMPLE: GSM280028
# 13-Aug-2019 12:22:55 DEBUG GEOparse - SAMPLE: GSM280081

# %%
gse_meta
# Out:
#          gse                                         cell.types  n.cell.types  \
# 15  GSE67321  B cells, CD4 T cells, CD8 T cells, Monocytes, ...             5
#
#                                                 title
# 15  [HG-U133_Plus_2] Affymetrix Human Genome U133 ...

# %%
gse_meta = gse_training[gse_training['gse']==gse_acc]
cds, gse_meta, stopToken = checkData(gse, gse_meta, sampleMeta, stopToken, logfile)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
cds.describe()
# cds.shape
# Out:
# name      GSM279753     GSM279759     GSM279777     GSM279743     GSM279799  \
# count  54675.000000  54675.000000  54675.000000  54675.000000  54675.000000
# mean     207.646697    129.019529     96.740784    111.815644    194.837422
# std      865.961949    542.669416    408.779436    470.493313    848.304612
# min        0.101672      0.046087      0.026784      0.051393      0.084276
# 25%        4.751340      4.317375      3.094385      3.094545      5.727040
# 50%       16.714000     16.435300     10.362500     10.625900     19.665600
# 75%       66.725800     74.205350     36.564950     43.009200     76.948400
# max    18598.700000  11937.300000  10329.700000  10944.500000  18592.400000
#
# name      GSM279796     GSM279792     GSM280019     GSM279787     GSM279791  \
# count  54675.000000  54675.000000  54675.000000  54675.000000  54675.000000
# mean     176.539497    205.154482    219.048470    135.461995    194.874365
# std      709.082803    756.773042    887.250557    586.776304    762.884900
# min        0.023115      0.063337      0.096625      0.049147      0.075795
# 25%        5.981305      6.458120      5.856320      4.077100      6.971775
# 50%       23.291000     26.028400     19.755400     14.790400     26.335000
# 75%      110.984000    133.412000     73.747300     68.006100    124.070000
# max    13305.600000  14183.900000  18282.200000  12779.100000  15185.900000
#
# name   ...     GSM280018     GSM279778     GSM279746     GSM279766  \
# count  ...  54675.000000  54675.000000  54675.000000  54675.000000
# mean   ...    206.159088    101.654435    171.728663    234.835017
# 1053_at      8.624167    9.236717    9.839555    9.245833    8.570820  ...
# 117_at       6.844059    9.844175    7.621459    8.764623    6.883254  ...
# 121_at       6.226050    6.210562    5.523449    5.667591    6.420119  ...
# 1255_g_at   -0.395967    1.589763    2.908429    2.101220    0.824442  ...
#
# name       GSM1644722  GSM1644739  GSM1644717  GSM1644729  GSM1644734  \
# ID_REF
# 1007_s_at    7.119003    6.083964    6.571323    6.450659    4.953680
# 1053_at      9.864819    8.691517    9.370469    9.019988   10.102553
# 117_at       7.030469    6.889814    9.287288    6.503131    9.044094
# 121_at       5.853926    5.574247    6.009278    5.622099    5.417785
# 1255_g_at    1.426764   -0.027147    1.188654    0.365513    1.519466
#
# name       GSM1644716  GSM1644720  GSM1644731  GSM1644723  GSM1644738
# ID_REF
# 1007_s_at    6.509789    7.969726    4.488309    8.342897    7.043312
# 1053_at      9.182446    9.754776    9.520318    9.725721    9.188616
# 117_at       9.586780    7.845333    8.804847    6.555716    6.958506
# 121_at       5.874386    6.369514    5.771769    5.338817    6.632403
# 1255_g_at    1.739066    0.919500    2.484246    1.330105    0.942105
#
# [5 rows x 30 columns]

# %%
cds, stopToken = getGeneNames(gse, cds, gse_meta, stopToken, logfile)
cds.shape
# Out:
# 100% |########################################################################|
# (22900, 31)

# %%
cds.set_index('gene_symbol_sql', inplace = True)
cds = cds.select_dtypes(include=['float'])
cds.rename(columns=lambda x: 'GSE_'+gse_acc+'__GSM_'+x+'__NORM_'+gse_norm, inplace = True)
cds.head()
# Out:
# name             GSE_GSE67321__GSM_GSM1644724__NORM_MAS5  \
# gene_symbol_sql
# MIR4640                                         8.186320
# RFC2                                            9.863170
# HSPA6                                           7.823253
# PAX8                                            3.669694
# GUCA1A                                          4.084550
#
# name             GSE_GSE67321__GSM_GSM1644741__NORM_MAS5  \
# gene_symbol_sql
# MIR4640                                         6.405475
# RFC2                                            8.931091
# HSPA6                                           7.640667
# PAX8                                            3.628897
# GUCA1A                                          3.070990
#
# name             GSE_GSE67321__GSM_GSM1644732__NORM_MAS5  \
# gene_symbol_sql
# MIR4640                                         6.151315
# RFC2                                            9.531811
# HSPA6                                           9.301866
# PAX8                                            3.858862
# GUCA1A                                          2.797293
#
# name             GSE_GSE67321__GSM_GSM1644728__NORM_MAS5  \
# gene_symbol_sql
# MIR4640                                         6.058091
# RFC2                                            8.836328
# HSPA6                                           5.828589
# PAX8                                            3.685271
# GUCA1A                                          1.758132
#
# name             GSE_GSE67321__GSM_GSM1644730__NORM_MAS5  \
# gene_symbol_sql
# MIR4640                                         6.568684
# RFC2                                            8.937179
# HSPA6                                           7.764520
# PAX8                                            3.925448
# GUCA1A                                          2.911316
#
# name             GSE_GSE67321__GSM_GSM1644737__NORM_MAS5  \
# gene_symbol_sql
# MIR4640                                         5.832947
# RFC2                                            8.514956
# HSPA6                                           7.021669
# PAX8                                            4.244738
# GUCA1A                                          2.655676
#
# name             GSE_GSE67321__GSM_GSM1644733__NORM_MAS5  \
# gene_symbol_sql
# MIR4640                                         6.120530
# RFC2                                            9.113707
# HSPA6                                          10.240083
# PAX8                                            4.540947
# GUCA1A                                          3.287016
#
# name             GSE_GSE67321__GSM_GSM1644721__NORM_MAS5  \
# gene_symbol_sql
# MIR4640                                         7.892587
# RFC2                                            9.767118
# HSPA6                                           7.907891
# PAX8                                            3.943143
# GUCA1A                                          3.691370
#
# name             GSE_GSE67321__GSM_GSM1644713__NORM_MAS5  \
# gene_symbol_sql
# MIR4640                                         5.754613
# RFC2                                            9.173564
# HSPA6                                           9.009093
# PAX8                                            3.084837
# GUCA1A                                          2.052389
#
# name             GSE_GSE67321__GSM_GSM1644726__NORM_MAS5  ...  \
# gene_symbol_sql                                           ...
# MIR4640                                         6.235573  ...
# RFC2                                            8.567793  ...
# HSPA6                                           6.777260  ...
# PAX8                                            4.811295  ...
# GUCA1A                                          2.278184  ...
#
# name             GSE_GSE67321__GSM_GSM1644722__NORM_MAS5  \
# gene_symbol_sql
# MIR4640                                         7.336039
# RFC2                                            9.710249
# HSPA6                                           7.176383
# PAX8                                            3.752265
# GUCA1A                                          3.246234
#
# name             GSE_GSE67321__GSM_GSM1644739__NORM_MAS5  \
# gene_symbol_sql
# MIR4640                                         6.550150
# RFC2                                            8.707085
# HSPA6                                           7.205648
# PAX8                                            3.896786
# GUCA1A                                          2.717233
#
# name             GSE_GSE67321__GSM_GSM1644717__NORM_MAS5  \
# gene_symbol_sql
# MIR4640                                         6.397942
# RFC2                                            9.416321
# HSPA6                                           9.558435
# PAX8                                            3.831352
# GUCA1A                                          3.009874
#
# name             GSE_GSE67321__GSM_GSM1644729__NORM_MAS5  \
# gene_symbol_sql
# MIR4640                                         5.650465
# RFC2                                            9.031655
# HSPA6                                           6.480373
# PAX8                                            3.632534
# GUCA1A                                          3.050075
#
# name             GSE_GSE67321__GSM_GSM1644734__NORM_MAS5  \
# gene_symbol_sql
# MIR4640                                         4.669985
# RFC2                                            9.960892
# HSPA6                                           9.444215
# PAX8                                            3.377475
# GUCA1A                                          2.838380
#
# name             GSE_GSE67321__GSM_GSM1644716__NORM_MAS5  \
# gene_symbol_sql
# MIR4640                                         6.060454
# RFC2                                            9.251538
# HSPA6                                           9.800316
# PAX8                                            3.443290
# GUCA1A                                          2.702088
#
# name             GSE_GSE67321__GSM_GSM1644720__NORM_MAS5  \
# gene_symbol_sql
# MIR4640                                         7.921254
# RFC2                                            9.639561
# HSPA6                                           8.071414
# PAX8                                            3.989049
# GUCA1A                                          3.246586
#
# name             GSE_GSE67321__GSM_GSM1644731__NORM_MAS5  \
# gene_symbol_sql
# MIR4640                                         4.113287
# RFC2                                            9.423716
# HSPA6                                           9.100246
# PAX8                                            3.818102
# GUCA1A                                          3.249211
#
# name             GSE_GSE67321__GSM_GSM1644723__NORM_MAS5  \
# gene_symbol_sql
# MIR4640                                         8.082374
# RFC2                                            9.655172
# HSPA6                                           7.204235
# PAX8                                            4.050327
# GUCA1A                                          3.650720
#
# name             GSE_GSE67321__GSM_GSM1644738__NORM_MAS5
# gene_symbol_sql
# MIR4640                                         6.611762
# RFC2                                            9.203375
# HSPA6                                           7.486899
# PAX8                                            3.835960
# GUCA1A                                          2.056001
#
# [5 rows x 30 columns]

# %%
stopToken = writeDataToSQL(cds, sampleMeta, gse_acc, stopToken, logfile)
stopToken
# Out:
# 0

# %%
success_gse.add(gse_acc)

# %%
# how to access annotations...
gse.gpls['GPL570'].table


#accessing a bit of data...
gse.gsms['GSM1899429'].table
#  Are these always the gsm data:
#   gse.gsms['GSM1899429'].columns

#accessing all data...
gse.pivot_samples('VALUE')
# Out:
# dict_keys(['GSM1899429', 'GSM1899430', 'GSM1899431', 'GSM1899432'])

# %%
gse.pivot_samples('VALUE').describe()
# Out:
# name      GSM992923     GSM992924     GSM992925     GSM992926     GSM992927  \
# count  54675.000000  54675.000000  54675.000000  54675.000000  54675.000000
# mean     829.874735    839.528630    836.948701    846.858511    827.108267
# std     2967.636520   3025.628799   2987.473973   3064.597301   2880.414560
# min        0.056351      0.075413      0.085526      0.109115      0.080421
# 25%       21.805180     19.793445     20.406930     20.518080     17.684010
# 50%       76.193220     71.691070     77.026280     75.364500     68.345470
# 75%      425.269250    408.766350    415.243650    418.980850    431.252400
# max    54410.330000  55280.450000  53582.280000  52328.810000  48240.920000
#
# name      GSM992928     GSM992929
# count  54675.000000  54675.000000
# mean     806.664502    817.170912
# std     2695.712450   2789.280198
# min        0.095650      0.092878
# 25%       18.610970     16.609245
# 50%       70.307690     64.891090
# 75%      445.289700    436.002050
# max    40161.000000  43560.330000

# %%
stopToken = writeDataToSQL(cds, sampleMeta, gse_acc, stopToken, logfile)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     394                                raw=raw, buffered=buffered,
# --> 395                                raw_as_string=raw_as_string)
#     396         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: BLOB/TEXT column 'gene_symbol_sql' used in key specification without a key length
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1243                     self.dialect.do_execute(
# -> 1244                         cursor, statement, parameters, context
#    1245                     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     549     def do_execute(self, cursor, statement, parameters, context=None):
# --> 550         cursor.execute(statement, parameters)
#     551
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     265                                          buffered=self._buffered,
# --> 266                                          raw_as_string=self._raw_as_string)
#     267         except MySQLInterfaceError as exc:
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     397             raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
# --> 398                                              sqlstate=exc.sqlstate)
#     399         except AttributeError:
#
# ProgrammingError: 1170 (42000): BLOB/TEXT column 'gene_symbol_sql' used in key specification without a key length
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-377-7d222433fa9e> in <module>
# ----> 1 stopToken = writeDataToSQL(cds, sampleMeta, gse_acc, stopToken, logfile)
#
# <ipython-input-376-580e7589b3f0> in writeDataToSQL(df, sampleMeta, gse_acc, stopToken, of)
#      15         ct_cds = df[ct_dict[ct]]
#      16         if all(ct.lower() != cellType for cellType in engine.table_names()):
# ---> 17             ct_cds.to_sql(ct.lower(), con=engine, chunksize=2000, index = True, index_label = 'gene_symbol_sql')
#      18 #             return ct_cds.head()
#      19         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     459                       index_label=index_label, schema=schema,
# --> 460                       chunksize=chunksize, dtype=dtype, method=method)
#     461
#     462
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1171                          if_exists=if_exists, index_label=index_label,
#    1172                          schema=schema, dtype=dtype)
# -> 1173         table.create()
#    1174         table.insert(chunksize, method=method)
#    1175         if (not name.isdigit() and not name.islower()):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     583                     "'{0}' is not valid for if_exists".format(self.if_exists))
#     584         else:
# --> 585             self._execute_create()
#     586
#     587     def _execute_insert(self, conn, keys, data_iter):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_create(self)
#     567         # Inserting table into database, add to MetaData object
#     568         self.table = self.table.tometadata(self.pd_sql.meta)
# --> 569         self.table.create()
#     570
#     571     def create(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\sql\schema.py in create(self, bind, checkfirst)
#     858         if bind is None:
#     859             bind = _bind_or_error(self)
# --> 860         bind._run_visitor(ddl.SchemaGenerator, self, checkfirst=checkfirst)
#     861
#     862     def drop(self, bind=None, checkfirst=False):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _run_visitor(self, visitorcallable, element, connection, **kwargs)
#    2031     ):
#    2032         with self._optional_conn_ctx_manager(connection) as conn:
# -> 2033             conn._run_visitor(visitorcallable, element, **kwargs)
#    2034
#    2035     class _trans_ctx(object):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _run_visitor(self, visitorcallable, element, **kwargs)
#    1605
#    1606     def _run_visitor(self, visitorcallable, element, **kwargs):
# -> 1607         visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#    1608
#    1609
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\sql\visitors.py in traverse_single(self, obj, **kw)
#     129             meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     130             if meth:
# --> 131                 return meth(obj, **kw)
#     132
#     133     def iterate(self, obj):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\sql\ddl.py in visit_table(self, table, create_ok, include_foreign_key_constraints, _is_metadata_operation)
#     831         if hasattr(table, "indexes"):
#     832             for index in table.indexes:
# --> 833                 self.traverse_single(index)
#     834
#     835         if self.dialect.supports_comments and not self.dialect.inline_comments:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\sql\visitors.py in traverse_single(self, obj, **kw)
#     129             meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     130             if meth:
# --> 131                 return meth(obj, **kw)
#     132
#     133     def iterate(self, obj):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\sql\ddl.py in visit_index(self, index)
#     860
#     861     def visit_index(self, index):
# --> 862         self.connection.execute(CreateIndex(index))
#     863
#     864
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\sql\ddl.py in _execute_on_connection(self, connection, multiparams, params)
#      70
#      71     def _execute_on_connection(self, connection, multiparams, params):
# ---> 72         return connection._execute_ddl(self, multiparams, params)
#      73
#      74     def execute(self, bind=None, target=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_ddl(self, ddl, multiparams, params)
#    1048             compiled,
#    1049             None,
# -> 1050             compiled,
#    1051         )
#    1052         if self._has_events or self.engine._has_events:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1246         except BaseException as e:
#    1247             self._handle_dbapi_exception(
# -> 1248                 e, statement, parameters, cursor, context
#    1249             )
#    1250
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1464                 util.raise_from_cause(newraise, exc_info)
#    1465             elif should_wrap:
# -> 1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
#    1468                 util.reraise(*exc_info)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     397     exc_type, exc_value, exc_tb = exc_info
#     398     cause = exc_value if exc_value is not exception else None
# --> 399     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     400
#     401
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151             value.__cause__ = cause
#     152         if value.__traceback__ is not tb:
# --> 153             raise value.with_traceback(tb)
#     154         raise value
#     155
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1242                 if not evt_handled:
#    1243                     self.dialect.do_execute(
# -> 1244                         cursor, statement, parameters, context
#    1245                     )
#    1246         except BaseException as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     548
#     549     def do_execute(self, cursor, statement, parameters, context=None):
# --> 550         cursor.execute(statement, parameters)
#     551
#     552     def do_execute_no_params(self, cursor, statement, context=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     264             result = self._cnx.cmd_query(stmt, raw=self._raw,
#     265                                          buffered=self._buffered,
# --> 266                                          raw_as_string=self._raw_as_string)
#     267         except MySQLInterfaceError as exc:
#     268             raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     396         except MySQLInterfaceError as exc:
#     397             raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
# --> 398                                              sqlstate=exc.sqlstate)
#     399         except AttributeError:
#     400             if self._unix_socket:
#
# ProgrammingError: (mysql.connector.errors.ProgrammingError) 1170 (42000): BLOB/TEXT column 'gene_symbol_sql' used in key specification without a key length
# [SQL: CREATE INDEX ix_endothelial_gene_symbol_sql ON endothelial (gene_symbol_sql)]
# (Background on this error at: http://sqlalche.me/e/f405)
